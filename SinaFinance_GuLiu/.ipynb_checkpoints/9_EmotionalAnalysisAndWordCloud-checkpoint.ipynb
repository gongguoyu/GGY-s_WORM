# %%
root_name = 'Sina_Finance_Comments_2879316_20180821'
print(root_name)
# Out:
# Sina_Finance_Comments_2879316_20180821

# %%
import pandas as pd
df = pd.read_csv(root_name+'_Cleaned.csv',encoding='utf-8')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  No  page          nick                 time  \
# 0          20            20  21     2         _S_酒红  2018-08-20 22:34:49
# 1          21            21  22     2  选择一条路然后一直走下去  2018-08-16 08:43:34
# 2          22            22  23     2       肥宅之王orz  2018-08-15 21:12:29
# 3          23            23  24     2         说个晚安吗  2018-08-15 17:42:03
# 4          24            24  25     2       绾起梨花月99  2018-08-14 21:29:01
#
#                                              content  area              ip  \
# 0                                        人在家中坐，锅从天上来    浙江    112.17.239.4
# 1                              80900010就没有不垮掉的一代[跪了]  青海西宁    111.44.141.9
# 2  赞同哥们你说的，本来事实就是这样，非要在一线干活才叫吃得了苦？熬夜写代码的画图的做方案的读书...  陕西西安  113.200.204.73
# 3                                 [good][good][good]    新疆  43.242.152.108
# 4                   我喝不起星巴克也买不起房[跪了][摊手][摊手][摊手][摊手]  广西贵港  117.181.90.157
#
#    length    ...     channel  hot level  login_type  media_type  \
# 0      11    ...          cj    0     0           0           0
# 1      31    ...          cj    0     2           0           0
# 2      74    ...          cj    0    11           0           0
# 3      36    ...          cj    0     1           0           0
# 4      32    ...          cj    0     0           0           0
#
#                                    mid       stamp    time_ymd  time_mdh  \
# 0  5B7AD187-7011EF04-14A2E4DC8-8C5-955  1534775689  2018-08-20  08-20 22
# 1  5B74C8B3-6F2C8D09-12EEE6933-8C5-8CB  1534380214  2018-08-16  08-16 08
# 2  5B7426BC-71C8CC49-14D2E179D-8C5-8E3  1534338749  2018-08-15  08-15 21
# 3  5B73F569-2BF2986C-15B085F4C-8C5-868  1534326123  2018-08-15  08-15 17
# 4   5B72D918-75B55A9D-DBC80468-8C5-823  1534253341  2018-08-14  08-14 21
#
#   cmntcount
# 0      3796
# 1      3795
# 2      3794
# 3      3793
# 4      3792
#
# [5 rows x 22 columns]

# %%
df =  pd.DataFrame(df,columns = ['nick','time','content'])
df.head()
# Out:
#            nick                 time  \
# 0         _S_酒红  2018-08-20 22:34:49
# 1  选择一条路然后一直走下去  2018-08-16 08:43:34
# 2       肥宅之王orz  2018-08-15 21:12:29
# 3         说个晚安吗  2018-08-15 17:42:03
# 4       绾起梨花月99  2018-08-14 21:29:01
#
#                                              content
# 0                                        人在家中坐，锅从天上来
# 1                              80900010就没有不垮掉的一代[跪了]
# 2  赞同哥们你说的，本来事实就是这样，非要在一线干活才叫吃得了苦？熬夜写代码的画图的做方案的读书...
# 3                                 [good][good][good]
# 4                   我喝不起星巴克也买不起房[跪了][摊手][摊手][摊手][摊手]

# %%
from snownlp import SnowNLP


def sentiment(content):
    s = SnowNLP(content)
    return s.sentiments

df['sentiment'] = df.content.apply(sentiment)

df_sent = df[['content', 'sentiment']]
df_sent.sort_values(by=['sentiment'],ascending=False)
# Out:
#                                                 content     sentiment
# 2199  最大的债务体系，最难偿还的债务不就是房贷吗？这个债务是谁给年轻人的呢？既然年轻人的债务使国家...  1.000000e+00
# 3482  我现在不咋喝星巴克了，喝茶比较多，一包高香铁观音就50块钱了[允悲][允悲][允悲][允悲]...  1.000000e+00
# 38    中国过去四十年，以50，60，70为主流的社会人群，没有积累起足够的技术积累，没有完善好相应...  1.000000e+00
# 777   不好意思我们整个宿舍没有人用苹果手机[拜拜][拜拜][拜拜][拜拜][拜拜][拜拜][拜拜]...  1.000000e+00
# 573   【中国买房人正带领国家走向危机？】从历史上来说，在中国靠借贷过活是可耻的。但当“房价世代”开...  1.000000e+00
# 905   真正的危机在于年轻人创造的价值不断被资本市场稀释，房地产就是最好的例子，年轻人将要付出更大的...  1.000000e+00
# 1402  新浪美股讯 8月7日消息 俄罗斯卫星网报道，据英国《金融时报》援引中国国际金融股份有限公司投...  1.000000e+00
# 2760       恰好相反，中国年轻一代一定带领这个国家摆脱各种历史积弊，让世界真正从内心服气和亲近中国。  1.000000e+00
# 617   新浪财经说是新浪美股讯报道的，新浪美股讯说是俄罗斯卫星网报道，俄罗斯卫星网说是英国《金融时报...  1.000000e+00
# 691   借贷行为确实存在着很多风险，但若说年轻人借贷会导致全国整个金融系统的悲剧性后果，甚至武断地说...  1.000000e+00
# 3724  这种垃圾文章将会误导政府，目前的危机主要出现在杠杆资产投资领域，说白了就是贷款按揭买房，年轻...  1.000000e+00
# 1943  2000年我高考，当时鼓励提前消费，记得很清楚，高考政治选择题里就有一个中国老太太和美国老太...  1.000000e+00
# 1612  其实我觉得说的没有大问题...传统第一产业年轻人不愿意做，都想做轻松报酬高，实际上哪有那么多...  9.999999e-01
# 1434  屌丝三大忌：赌博、创业、投资。赌博赢的是庄家，屌丝创业只在社会变革时期有可能成功，如改开初期...  9.999999e-01
# 3191  促进消费拉动内需可是我国社会发展的未来方向，没有当代年轻人的消费观念，哪来的经济增长，然后大...  9.999999e-01
# 1464   屌丝三大忌：赌博、创业、投资。赌博赢的是庄家，屌丝创业只在社会变革时期有可能成功，投资多半被骗。  9.999998e-01
# 1603  原文重点放在借贷上，评论重点将借贷视作常态，将消费对象中的大额花销拿出来比对，房子or星巴克...  9.999997e-01
# 690   外甥12岁，跟我说他们的同学都在比穿着，要穿耐克、阿迪等大牌，比手机比家世，而我外甥不在乎什...  9.999994e-01
# 855     我的意思说，这篇文章说中国年轻人带国家走向危机，我心想那不生不就得了，越生年轻人越多[允悲]。  9.999992e-01
# 2700  “俄罗斯卫星网报道，据英国《金融时报》（FT）援引中国国际金融股份有限公司（CICC）投行的...  9.999989e-01
# 668   学会一定程度上迎合环境也是情商的一种啊……有的人能消费名牌 喜欢就喜欢咯 你就跟他们说几句 ...  9.999987e-01
# 721   主流的媒体舆论引导孩子的三观，而很多的无良媒体影响着孩子的性格，下一代都快被毁了，世界观、人...  9.999986e-01
# 1066                               [嘻嘻][嘻嘻][嘻嘻][嘻嘻][嘻嘻]  9.999984e-01
# 3153  中国人的传统习惯是"积谷防饥",消费相对保守,这是非常好的传统,也是社会安定的一根"定海神针...  9.999979e-01
# 1138                              哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈今日沙雕标题  9.999979e-01
# 1634  报道的客观对象从“年轻人贷款消费”一下子跳换到了“家庭债务”和“信贷”，这两者一定有必然联系...  9.999977e-01
# 908   我们都很懂得最大程度对自己好，没有上一辈人艰苦奋斗精神。我觉得这样挺好的。人生在世，活透彻点...  9.999966e-01
# 2282  文章内容和国家现行政策不符。前几年大喊特喊的“拉动消费”，现在又反过来指责我们90后，00后...  9.999962e-01
# 1802                     我爸同事卖房辞工拿着一千多万回家盖楼去了，我爸：羡慕羡慕羡慕  9.999961e-01
# 1913                        美国人借贷就是经济有活力，中国人借贷就是走向危机，有趣  9.999960e-01
# ...                                                 ...           ...
# 153        我也不借，但是他这觉得正常消费是不对的，我就不能忍，累死累活赚点钱还不能花的舒服吗~~~  1.447453e-03
# 271   我的老家东北，你知道有多少公务员在四十岁的时候实现半退休吗？十年前有多少人在上班期间就是打麻...  1.274586e-03
# 3414                        房子我是买不起了。难道钱不花，把钱存银行等通货膨胀？？  1.215628e-03
# 1757   然后半年后房价涨了，你再也买不起房了，很快房租也跟着涨了，交不起房租房东让你明天就搬出去[二哈]  8.355688e-04
# 276   哪个年轻人不靠借贷生活！谁不欠银行上百万房贷！！！不借贷买不起啊！！！怎么不去谴责一下那些让...  8.080530e-04
# 1096                         迟早的事...我觉得他扣迟了，扣早点还能再忽悠一波人  7.784706e-04
# 578                有房的早就有了，没房的还是没。小城市房不值钱大城市买不起，不就是这样么~  7.706269e-04
# 1035      公安局-个人业务-出入境管理-国籍事务-填写申请-退籍证书费用200元。没有你想的那么难。  7.040571e-04
# 1709  本来就该花明天的钱啊 反正我单位是先工作月底才发工资…我不花信用卡这个月吃什么？？？怎么不说...  6.897939e-04
# 3722         你他妈别废话，好像你不吃不喝，不买手机，没有贷款似的，还有比房贷更能压垮一个人的吗？  6.682167e-04
# 3233  学夷人借贷消费的确有问题，现在的年青一辈根本沒经历过风浪，你们以为前人储蓄习惯是天上掉下来的...  6.618089e-04
# 298   中纪委看大门的狗都不认得你，别说扫地的阿姨，打饭的大妈了，不守规矩，就禁止你坐地铁，法院大门...  5.794515e-04
# 3743                                          无耻，无耻，无耻。  5.101668e-04
# 2457    就他妈一句话：勤勤恳恳工作的本地人，也他妈照样买不起房！！！买不起房，还不能自己买点开心了？！  4.507974e-04
# 213                      见过无耻的，没见过这么无耻的，我们为什么贷款  你不知道ma  4.446815e-04
# 677             对不住了，本韭菜实在买不起房。 小品里说的好“家有房屋千万所，睡觉只需三尺宽。  3.165878e-04
# 3676                           保持队形各位[吐][吐][吐][吐][吐][吐]  2.672034e-04
# 3103                我都消费降级得不行了你还给我扣锅？我消费降级是谁的锅心里还没点X数吗？  2.297361e-04
# 2594                        作为对这个国家失望透顶的90后觉得这锅甩的很恶心很无耻  2.152079e-04
# 2917                           一大早看到这么恶心的负智商博眼球文章真是让人想吐  2.121613e-04
# 2810                                明明是司机不行 竟然在这里怪乘客 无耻  1.043747e-04
# 2539                         不结婚交税 不生孩交税 不消费交税 一键解决所有问题  9.360901e-05
# 251                 要是啥都不买，攒钱买房，不说买不起泡沫了呢？攒钱炒股P2P还不如花了呢  8.738731e-05
# 3006             瞎扯淡，有本事找银行去啊，银行可是天天打电话劝年轻人办信用卡，办分期还款的。  6.308045e-05
# 2686              [吃瓜][吃瓜]消费都50%以上了，何止破6，随便跌几个点gdp就不能看了  5.559835e-05
# 3056           我贷款买房子车位车子有错？我每个月按时还款你管我？钱越来越不值钱，不贷款才是傻呢  5.435991e-05
# 106   10年前贷款买房的人都赚翻了，把钱存银行的，都傻眼了对吧？提前消费，贷款消费，对拉动内需意义...  5.068154e-05
# 1643                         反思哈自己、为啥不生孩子、为啥不炒股、为啥不买p2p  4.112690e-05
# 3680                     保持队形各位[吐][吐][吐][吐][吐][吐][吐][吐]  1.662388e-05
# 3629            這個屎盆子扣得噁心[吐][吐][吐][吐][吐][吐][吐][吐][吐][吐]  6.689213e-08
#
# [3817 rows x 2 columns]

# %%
import jieba.analyse
all_content = df.content.values.tolist()
extract_tags = "  ".join(jieba.analyse.extract_tags(' '.join(all_content), topK=200, withWeight=False, allowPOS=('ns', 'n')))
print(extract_tags)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\G\AppData\Local\Temp\jieba.cache
# Loading model cost 0.812 seconds.
# Prefix dict has been built succesfully.
# 年轻人  买房  摊手  借贷  房子  贷款  国家  韭菜  文章  危机  孩子  债务  房价  中国  标题  手机  评论  买手机  背锅  不语  信用卡  大牌  拜拜  买房子  衣服  银行  咖啡  父母  智能手机  大家  篇文章  经济  问题  感觉  时候  全款  意思  媒体  内需  社会  俄罗斯  黑锅  一代人  原文  东西  美国  卧槽  家庭  大锅  杠杆  租房  地方  财经  套房  砖家  年轻一代  校园  有点  新闻  逻辑  脑子  负债  花钱  消费观念  白条  恶心  干嘛  人家  能力  苹果  道理  奢侈品  屌丝  城市  毛病  信贷  水平  老年人  习惯  智商  无力  数据  钱包  生娃  小编  广州  物价  作者  祖国  节奏  英国  老一辈  中年人  言论  关键  屁事  内容  车贷  压力  时代  学区  生小孩  阴险  责任  黑线  买车  历史  买点  结果  垃圾  穷人  老师  存款  利息  问问  人生  消费观  消费主义  世界  北京  大学生  神经病  国际金融  气死  租金  合格  降级  人民  长大  编辑  故事  眼球  企业  代表  贡献  车子  风险  事情  单身  价值观  高利贷  后背  裤腰带  同龄人  兄弟  爷爷奶奶  奶茶  月薪  专家  狗屁  过日子  要点  县城  白眼  独生子女  基本  爸爸  课本上  博主  沙雕  辣鸡  背锅侠  次贷  玩玩  负债率  重点  报章  过度  拖后腿  帽子  医疗  政府  价格  小鸟  老人  外国  玩乐  蚂蚁  代人  回家  年青人  通篇  读书  创业  经济学  交税  公积金  结论  领路人  坏事  丈母娘  小时候  啥意思  样子  马车  咖啡馆  身体  房奴  苦哈哈  全部

# %%
import jieba
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

all_content = df.content.values.tolist()
print(len(all_content), '\n', all_content[-1])

segment = []
for line in all_content:
    try:
        segs = jieba.lcut(line)
        #print(line)
        #print(segs)
        for seg in segs:
            if len(seg)>1 and seg != '\r\n':
                segment.append(seg)
    except:
        print(line)
        continue      

# 去停用词
words_df = pd.DataFrame({"segment": segment})

words_stat = words_df.groupby(by=['segment'])['segment'].agg({"计数": np.size})


words_stat = words_stat.reset_index().sort_values(by=["计数"], ascending=False)
words_stat.head(20)
# Out:
# 3817
#  抱歉，穷困潦倒的年轻人不背这锅，[吃瓜]
# D:\Anaconda2\envs\python36\lib\site-packages\ipykernel\__main__.py:25: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#      segment   计数
# 2757     年轻人  537
# 3101      我们  263
# 842       买房  250
# 4151      消费  205
# 199     doge  196
# 612       不是  189
# 2058      国家  180
# 3666     星巴克  167
# 2620      就是  157
# 878       二哈  150
# 4375      现在  148
# 5520      贷款  143
# 970       什么  143
# 3157      房子  142
# 5135      自己  141
# 746       中国  141
# 5693      这个  138
# 1917     哈哈哈  136
# 1222      允悲  134
# 2962      怎么  124

# %%
from pyecharts import WordCloud
wordcloud = WordCloud(width=800, height=520)
wordcloud.add("评论词云", words_stat['segment'], words_stat['计数'], word_size_range=[20, 100])
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="ebf789bf951f4dd283ad6a04cc627448" style="width:800px;height:520px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_ebf789bf951f4dd283ad6a04cc627448 = echarts.init(document.getElementById('ebf789bf951f4dd283ad6a04cc627448'), 'light', {renderer: 'canvas'});
#
# var option_ebf789bf951f4dd283ad6a04cc627448 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3891710,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u8bc4\u8bba\u8bcd\u4e91",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u5e74\u8f7b\u4eba",
#                     "value": 537,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,8,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6211\u4eec",
#                     "value": 263,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,29,16)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e70\u623f",
#                     "value": 250,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,77,44)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6d88\u8d39",
#                     "value": 205,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(105,17,17)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "doge",
#                     "value": 196,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,3,18)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u662f",
#                     "value": 189,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,106,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56fd\u5bb6",
#                     "value": 180,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,74,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u661f\u5df4\u514b",
#                     "value": 167,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,54,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c31\u662f",
#                     "value": 157,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(156,67,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e8c\u54c8",
#                     "value": 150,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(60,109,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73b0\u5728",
#                     "value": 148,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,57,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d37\u6b3e",
#                     "value": 143,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,79,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ec0\u4e48",
#                     "value": 143,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,53,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u623f\u5b50",
#                     "value": 142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(0,18,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u81ea\u5df1",
#                     "value": 141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(129,135,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd",
#                     "value": 141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,47,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd9\u4e2a",
#                     "value": 138,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,135,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54c8\u54c8\u54c8",
#                     "value": 136,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,148,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5141\u60b2",
#                     "value": 134,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(75,10,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u600e\u4e48",
#                     "value": 124,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(96,106,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e70\u4e0d\u8d77",
#                     "value": 122,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,141,122)"
#                         }
#                     }
