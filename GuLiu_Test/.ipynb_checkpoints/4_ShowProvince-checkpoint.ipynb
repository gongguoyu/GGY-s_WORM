# %%
import pandas as pd
df = pd.read_csv('Sina_Finance_Comments_2879316_20180821_Cleaned.csv',encoding='utf-8')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  No  page          nick                 time  \
# 0          20            20  21     2         _S_酒红  2018-08-20 22:34:49
# 1          21            21  22     2  选择一条路然后一直走下去  2018-08-16 08:43:34
# 2          22            22  23     2       肥宅之王orz  2018-08-15 21:12:29
# 3          23            23  24     2         说个晚安吗  2018-08-15 17:42:03
# 4          24            24  25     2       绾起梨花月99  2018-08-14 21:29:01
#
#                                              content  area              ip  \
# 0                                        人在家中坐，锅从天上来    浙江    112.17.239.4
# 1                              80900010就没有不垮掉的一代[跪了]  青海西宁    111.44.141.9
# 2  赞同哥们你说的，本来事实就是这样，非要在一线干活才叫吃得了苦？熬夜写代码的画图的做方案的读书...  陕西西安  113.200.204.73
# 3                                 [good][good][good]    新疆  43.242.152.108
# 4                   我喝不起星巴克也买不起房[跪了][摊手][摊手][摊手][摊手]  广西贵港  117.181.90.157
#
#    length    ...     channel  hot level  login_type  media_type  \
# 0      11    ...          cj    0     0           0           0
# 1      31    ...          cj    0     2           0           0
# 2      74    ...          cj    0    11           0           0
# 3      36    ...          cj    0     1           0           0
# 4      32    ...          cj    0     0           0           0
#
#                                    mid       stamp    time_ymd  time_mdh  \
# 0  5B7AD187-7011EF04-14A2E4DC8-8C5-955  1534775689  2018-08-20  08-20 22
# 1  5B74C8B3-6F2C8D09-12EEE6933-8C5-8CB  1534380214  2018-08-16  08-16 08
# 2  5B7426BC-71C8CC49-14D2E179D-8C5-8E3  1534338749  2018-08-15  08-15 21
# 3  5B73F569-2BF2986C-15B085F4C-8C5-868  1534326123  2018-08-15  08-15 17
# 4   5B72D918-75B55A9D-DBC80468-8C5-823  1534253341  2018-08-14  08-14 21
#
#   cmntcount
# 0      3796
# 1      3795
# 2      3794
# 3      3793
# 4      3792
#
# [5 rows x 22 columns]

# %%
df[['area']]
# Out:
#          area
# 0          浙江
# 1        青海西宁
# 2        陕西西安
# 3          新疆
# 4        广西贵港
# 5          北京
# 6        江西南昌
# 7     内蒙古呼和浩特
# 8          北京
# 9        江苏徐州
# 10       河北沧州
# 11       河南濮阳
# 12       安徽亳州
# 13       山东临沂
# 14       山东滨州
# 15         宁夏
# 16       江西南昌
# 17       浙江台州
# 18       甘肃白银
# 19         上海
# 20       广东深圳
# 21       河南开封
# 22       湖北武汉
# 23         江西
# 24       湖南长沙
# 25         广东
# 26         北京
# 27       江苏南通
# 28       湖北潜江
# 29       江西南昌
# ...       ...
# 3787     浙江杭州
# 3788       福建
# 3789     浙江绍兴
# 3790     山东青岛
# 3791     江苏徐州
# 3792     福建福州
# 3793     安徽合肥
# 3794     河南周口
# 3795     江西南昌
# 3796       北京
# 3797     浙江绍兴
# 3798       上海
# 3799     江苏徐州
# 3800     浙江杭州
# 3801     河南郑州
# 3802     江苏无锡
# 3803     山东德州
# 3804     山西吕梁
# 3805     江苏无锡
# 3806     四川成都
# 3807       北京
# 3808     浙江杭州
# 3809       北京
# 3810       上海
# 3811     安徽淮北
# 3812  内蒙古乌兰察布
# 3813  内蒙古呼和浩特
# 3814       北京
# 3815     贵州贵阳
# 3816       上海
#
# [3817 rows x 1 columns]

# %%
area_count = df.groupby('area')['area'].count().sort_values(ascending=False)
area_name = list(area_count.index)
area_values = area_count.values
print(len(area_name),len(area_values))
print(area_count)
# Out:
# 341 341
# area
# 北京            320
# 上海            281
# 广东广州          180
# 四川成都          136
# 广东深圳          130
# 湖北武汉          115
# 重庆             97
# 江苏南京           93
# 浙江杭州           87
# 陕西西安           74
# 福建福州           74
# 浙江             69
# 江苏苏州           63
# 安徽合肥           51
# 天津             45
# 山东济南           43
# 山东青岛           42
# 江苏徐州           42
# 江苏无锡           42
# 江西南昌           42
# 辽宁沈阳           40
# 河南郑州           39
# 香港             38
# 广东佛山           38
# 广东             38
# 湖南长沙           36
# 云南昆明           31
# 山西太原           30
# 北京海淀           30
# 广西南宁           29
#              ...
# 广西百色            1
# 安徽马鞍山           1
# 黑龙江伊春           1
# 山东滨州            1
# 山东莱芜            1
# 山东菏泽            1
# 山西朔州            1
# 广东云浮            1
# 马来西亚            1
# 广东梅州            1
# 广东汕尾            1
# 广东河源            1
# 广东潮州            1
# 广东肇庆            1
# 广西贵港            1
# 江西景德镇           1
# 意大利             1
# 意大利托斯卡纳         1
# 意大利皮埃蒙特         1
# 新疆伊犁哈萨克自治州      1
# 新疆塔城地区          1
# 新疆石河子           1
# 新西兰             1
# 日本和歌山县          1
# 日本岐阜县           1
# 日本滋贺县           1
# 青海              1
# 黑龙江鸡西           1
# 江西抚州            1
# 青海海东            1
# Name: area, Length: 341, dtype: int64

# %%
area_len_2 = []
area_len_3 = []
area_len_4 = []
area_len_5 = []
unchina = ['英国','美国','日本','瑞士','法国','瑞典','越南','泰国',
           '意大利','加拿大','菲律宾','新加坡','新西兰','伊拉克','爱尔兰','安哥拉',
           '澳大利亚', '大韩民国', '马来西亚']
droped = []
for area in area_name:
    #print(area)
    for unarea in unchina:
        #if  unicode(unarea, 'utf-8') in area: 
        if  unarea in area: 
            droped.append(area)
    if len(area)==2 and area not in droped: area_len_2.append(area) # 我国共有34个省级行政区域，包括23个省，5个自治区，4个直辖市，2个特别行政区。
    if len(area)==3 and area not in droped: area_len_3.append(area)
    if len(area)==4 and area not in droped: area_len_4.append(area)
    if len(area)>=5 and area not in droped: area_len_5.append(area)
        
print(len(droped),'\n', droped)
print(len(area_len_2),'\n', area_len_2)
print(len(area_len_3),'\n', area_len_3)
print(len(area_len_4),'\n', area_len_4)
print(len(area_len_5),'\n', area_len_5)
# Out:
# 47
#  ['澳大利亚', '日本', '英国英格兰', '新加坡', '美国', '美国加利福尼亚州', '美国纽约州', '美国伊利诺伊州', '英国', '大韩民国', '法国', '英国苏格兰', '加拿大安大略', '瑞典', '加拿大不列颠哥伦比亚', '美国新泽西州', '美国康乃狄克州', '美国马里兰州', '美国德克萨斯州', '泰国', '美国佛罗里达州', '美国俄亥俄州', '加拿大艾伯塔', '安哥拉', '加拿大', '澳大利亚澳大利亚首都领地', '爱尔兰', '瑞士', '美国乔治亚', '美国俄勒冈州', '美国宾夕法尼亚州', '美国密歇根州', '美国密苏里州', '美国弗吉尼亚州', '美国田纳西州', '美国路易斯安那州', '菲律宾', '菲律宾西米沙鄢', '越南胡志明市', '马来西亚', '意大利', '意大利托斯卡纳', '意大利皮埃蒙特', '新西兰', '日本和歌山县', '日本岐阜县', '日本滋贺县']
# 28
#  ['北京', '上海', '重庆', '浙江', '天津', '香港', '广东', '河北', '福建', '湖南', '山东', '云南', '吉林', '河南', '四川', '贵州', '广西', '辽宁', '山西', '湖北', '宁夏', '新疆', '江苏', '江西', '澳门', '甘肃', '海南', '青海']
# 2
#  ['黑龙江', '内蒙古']
# 227
#  ['广东广州', '四川成都', '广东深圳', '湖北武汉', '江苏南京', '浙江杭州', '陕西西安', '福建福州', '江苏苏州', '安徽合肥', '山东济南', '山东青岛', '江苏徐州', '江苏无锡', '江西南昌', '辽宁沈阳', '河南郑州', '广东佛山', '湖南长沙', '云南昆明', '山西太原', '北京海淀', '广西南宁', '广东东莞', '河南开封', '甘肃兰州', '江苏南通', '辽宁大连', '浙江绍兴', '吉林长春', '贵州贵阳', '辽宁盘锦', '浙江宁波', '福建厦门', '浙江温州', '山东临沂', '浙江金华', '江苏常州', '山西晋城', '河南洛阳', '四川内江', '广东汕头', '江苏扬州', '江苏泰州', '山东淄博', '广东中山', '湖北宜昌', '山东烟台', '福建泉州', '浙江嘉兴', '浙江湖州', '山东济宁', '海南海口', '河北保定', '广东惠州', '浙江台州', '山东潍坊', '山西大同', '宁夏银川', '河北邯郸', '河南周口', '河北廊坊', '广西柳州', '江西九江', '湖北襄阳', '青海西宁', '安徽淮北', '河北沧州', '河北承德', '浙江丽水', '河北唐山', '广东韶关', '四川绵阳', '江苏盐城', '安徽芜湖', '河南南阳', '陕西宝鸡', '湖北黄冈', '湖北随州', '广东揭阳', '天津塘沽', '山西长治', '湖南常德', '贵州遵义', '辽宁朝阳', '江西上饶', '辽宁营口', '山东德州', '江西宜春', '辽宁鞍山', '广西桂林', '福建龙岩', '陕西咸阳', '四川南充', '山西运城', '辽宁抚顺', '山东聊城', '山东东营', '安徽六安', '安徽淮南', '河北衡水', '四川宜宾', '湖北荆州', '海南三亚', '河南濮阳', '广西北海', '广西梧州', '广西河池', '河南漯河', '四川自贡', '云南曲靖', '广东阳江', '湖南益阳', '湖南衡阳', '湖南邵阳', '江苏宿迁', '湖南湘潭', '广东湛江', '广东茂名', '山西临汾', '安徽滁州', '安徽阜阳', '辽宁锦州', '山东威海', '山东日照', '湖北咸宁', '山西吕梁', '山西晋中', '湖南株洲', '广东江门', '广东清远', '广西玉林', '甘肃武威', '福建宁德', '江西赣州', '河南安阳', '陕西延安', '福建莆田', '河南许昌', '江苏镇江', '山西阳泉', '辽宁丹东', '北京朝阳', '宁夏吴忠', '浙江衢州', '浙江舟山', '贵州毕节', '安徽池州', '云南保山', '湖北黄石', '河北邢台', '湖南岳阳', '安徽黄山', '山东枣庄', '河南新乡', '辽宁阜新', '陕西汉中', '安徽安庆', '吉林松原', '山东泰安', '上海徐汇', '辽宁辽阳', '江苏淮安', '北京东城', '辽宁本溪', '湖南郴州', '四川雅安', '云南普洱', '江西萍乡', '四川泸州', '广西钦州', '四川资阳', '江西鹰潭', '福建漳州', '广西崇左', '福建南平', '广东珠海', '四川达州', '陕西铜川', '福建三明', '四川德阳', '甘肃白银', '河南鹤壁', '四川广安', '吉林通化', '四川乐山', '四川广元', '云南昭通', '安徽亳州', '上海黄浦', '四川眉山', '宁夏固原', '吉林白山', '云南临沧', '四川遂宁', '陕西商洛', '安徽蚌埠', '安徽铜陵', '陕西渭南', '湖北孝感', '湖北潜江', '湖北荆门', '湖南娄底', '湖南怀化', '湖南永州', '甘肃天水', '甘肃定西', '甘肃张掖', '西藏拉萨', '辽宁铁岭', '河南焦作', '河南商丘', '河南信阳', '广西百色', '山东滨州', '山东莱芜', '山东菏泽', '山西朔州', '广东云浮', '广东梅州', '广东汕尾', '广东河源', '广东潮州', '广东肇庆', '广西贵港', '江西抚州', '青海海东']
# 37
#  ['内蒙古呼和浩特', '黑龙江哈尔滨', '河北石家庄', '新疆乌鲁木齐', '内蒙古包头', '江苏连云港', '河北秦皇岛', '内蒙古赤峰', '新疆昌吉回族自治州', '青海海南藏族自治州', '黑龙江齐齐哈尔', '河南驻马店', '内蒙古通辽', '内蒙古鄂尔多斯', '黑龙江大庆', '河南三门峡', '河南平顶山', '黑龙江牡丹江', '新疆巴音郭楞蒙古自治州', '湖南湘西土家族苗族自治州', '内蒙古兴安盟', '河北张家口', '云南红河哈尼族彝族自治州', '黑龙江绥化', '云南怒江傈僳族自治州', '云南大理白族自治州', '内蒙古呼伦贝尔', '内蒙古乌兰察布', '湖北恩施土家族苗族自治州', '辽宁葫芦岛', '安徽马鞍山', '黑龙江伊春', '江西景德镇', '新疆伊犁哈萨克自治州', '新疆塔城地区', '新疆石河子', '黑龙江鸡西']

# %%
prolist = '北京市，天津市，上海市，重庆市，河北省，山西省，辽宁省，吉林省，江苏省，浙江省，安徽省，福建省，\
江西省，山东省，河南省，湖北省，湖南省，广东省，海南省，四川省，贵州省，云南省，陕西省，甘肃省，\
青海省，台湾省，广西，西藏，宁夏，新疆，香港，澳门，内蒙古，黑龙江省'
prolist = prolist.replace('市', '').replace('省', '').split('，')
print(len(prolist), prolist)
# Out:
# 34 ['北京', '天津', '上海', '重庆', '河北', '山西', '辽宁', '吉林', '江苏', '浙江', '安徽', '福建', '江西', '山东', '河南', '湖北', '湖南', '广东', '海南', '四川', '贵州', '云南', '陕西', '甘肃', '青海', '台湾', '广西', '西藏', '宁夏', '新疆', '香港', '澳门', '内蒙古', '黑龙江']

# %%
def get_pro(area):
    prolist = ['北京', '天津', '上海', '重庆', '河北', '山西', '辽宁', '吉林', '江苏', '浙江', '安徽', '福建', '江西', '山东', '河南', '湖北', '湖南', '广东', '海南', '四川', '贵州', '云南', '陕西', '甘肃', '青海', '台湾', '广西', '西藏', '宁夏', '新疆', '香港', '澳门', '内蒙古', '黑龙江']
    for pro in prolist:
        if pro in area:
            return pro
    return "海外"
df['pro'] = df.area.apply(get_pro)
df[['area','pro']]
# Out:
#          area  pro
# 0          浙江   浙江
# 1        青海西宁   青海
# 2        陕西西安   陕西
# 3          新疆   新疆
# 4        广西贵港   广西
# 5          北京   北京
# 6        江西南昌   江西
# 7     内蒙古呼和浩特  内蒙古
# 8          北京   北京
# 9        江苏徐州   江苏
# 10       河北沧州   河北
# 11       河南濮阳   河南
# 12       安徽亳州   安徽
# 13       山东临沂   山东
# 14       山东滨州   山东
# 15         宁夏   宁夏
# 16       江西南昌   江西
# 17       浙江台州   浙江
# 18       甘肃白银   甘肃
# 19         上海   上海
# 20       广东深圳   广东
# 21       河南开封   河南
# 22       湖北武汉   湖北
# 23         江西   江西
# 24       湖南长沙   湖南
# 25         广东   广东
# 26         北京   北京
# 27       江苏南通   江苏
# 28       湖北潜江   湖北
# 29       江西南昌   江西
# ...       ...  ...
# 3787     浙江杭州   浙江
# 3788       福建   福建
# 3789     浙江绍兴   浙江
# 3790     山东青岛   山东
# 3791     江苏徐州   江苏
# 3792     福建福州   福建
# 3793     安徽合肥   安徽
# 3794     河南周口   河南
# 3795     江西南昌   江西
# 3796       北京   北京
# 3797     浙江绍兴   浙江
# 3798       上海   上海
# 3799     江苏徐州   江苏
# 3800     浙江杭州   浙江
# 3801     河南郑州   河南
# 3802     江苏无锡   江苏
# 3803     山东德州   山东
# 3804     山西吕梁   山西
# 3805     江苏无锡   江苏
# 3806     四川成都   四川
# 3807       北京   北京
# 3808     浙江杭州   浙江
# 3809       北京   北京
# 3810       上海   上海
# 3811     安徽淮北   安徽
# 3812  内蒙古乌兰察布  内蒙古
# 3813  内蒙古呼和浩特  内蒙古
# 3814       北京   北京
# 3815     贵州贵阳   贵州
# 3816       上海   上海
#
# [3817 rows x 2 columns]

# %%
pro_count = df.groupby('pro')['pro'].count().sort_values(ascending=False)
pro_count
# Out:
# pro
# 广东     477
# 北京     354
# 江苏     321
# 上海     284
# 浙江     252
# 四川     191
# 山东     180
# 湖北     159
# 福建     135
# 海外     133
# 河南     128
# 辽宁     115
# 河北     100
# 重庆      97
# 陕西      93
# 安徽      88
# 湖南      86
# 山西      78
# 江西      71
# 广西      69
# 云南      63
# 内蒙古     52
# 天津      50
# 黑龙江     39
# 香港      38
# 甘肃      35
# 贵州      33
# 吉林      32
# 新疆      22
# 海南      16
# 宁夏      14
# 青海       9
# 澳门       2
# 西藏       1
# Name: pro, dtype: int64

# %%
from pyecharts import Bar
bar = Bar("省份分布")
bar.use_theme("macarons") # 换主题
bar.add("省份", pro_count.index, pro_count.values,is_label_show=True,xaxis_interval=0,xaxis_rotate=-45)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'macarons': '/nbextensions/echarts-themes-js/macarons'
#         }
#     });
# </script>
#     <div id="5bbab6f063734c7d9ddf192a09413ca0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'macarons'], function(echarts) {
#
# var myChart_5bbab6f063734c7d9ddf192a09413ca0 = echarts.init(document.getElementById('5bbab6f063734c7d9ddf192a09413ca0'), 'macarons', {renderer: 'canvas'});
#
# var option_5bbab6f063734c7d9ddf192a09413ca0 = {
#     "title": [
#         {
#             "text": "\u7701\u4efd\u5206\u5e03",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2903335,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7701\u4efd",
#             "data": [
#                 477.0,
#                 354.0,
#                 321.0,
#                 284.0,
#                 252.0,
#                 191.0,
#                 180.0,
#                 159.0,
#                 135.0,
#                 133.0,
#                 128.0,
#                 115.0,
#                 100.0,
#                 97.0,
#                 93.0,
#                 88.0,
#                 86.0,
#                 78.0,
#                 71.0,
#                 69.0,
#                 63.0,
#                 52.0,
#                 50.0,
#                 39.0,
#                 38.0,
#                 35.0,
#                 33.0,
#                 32.0,
#                 22.0,
#                 16.0,
#                 14.0,
#                 9.0,
#                 2.0,
#                 1.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2903335
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7701\u4efd"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": -45,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u5e7f\u4e1c",
#                 "\u5317\u4eac",
#                 "\u6c5f\u82cf",
#                 "\u4e0a\u6d77",
#                 "\u6d59\u6c5f",
#                 "\u56db\u5ddd",
#                 "\u5c71\u4e1c",
#                 "\u6e56\u5317",
#                 "\u798f\u5efa",
#                 "\u6d77\u5916",
#                 "\u6cb3\u5357",
#                 "\u8fbd\u5b81",
#                 "\u6cb3\u5317",
#                 "\u91cd\u5e86",
#                 "\u9655\u897f",
#                 "\u5b89\u5fbd",
#                 "\u6e56\u5357",
#                 "\u5c71\u897f",
#                 "\u6c5f\u897f",
#                 "\u5e7f\u897f",
#                 "\u4e91\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u5929\u6d25",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u9999\u6e2f",
#                 "\u7518\u8083",
#                 "\u8d35\u5dde",
#                 "\u5409\u6797",
#                 "\u65b0\u7586",
#                 "\u6d77\u5357",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u6fb3\u95e8",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": []
# };
# myChart_5bbab6f063734c7d9ddf192a09413ca0.setOption(option_5bbab6f063734c7d9ddf192a09413ca0);
#
#     });
# </script>

# %%
from pyecharts import Map
mapp = Map("省份分布情况", width=800, height=600)
#mapp.use_theme("westeros") # 换主题
mapp.add("", pro_count.index, pro_count.values, maptype='china', is_visualmap=True,
             visual_range=[0, 480], is_map_symbol_show=False, visual_text_color='#000', is_label_show=True)
mapp
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e79f254893414d14a510c86ffe5bf41b" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_e79f254893414d14a510c86ffe5bf41b = echarts.init(document.getElementById('e79f254893414d14a510c86ffe5bf41b'), 'light', {renderer: 'canvas'});
#
# var option_e79f254893414d14a510c86ffe5bf41b = {
#     "title": [
#         {
#             "text": "\u7701\u4efd\u5206\u5e03\u60c5\u51b5",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4279597,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 477.0
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 354.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 321.0
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 284.0
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 252.0
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 191.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 180.0
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 159.0
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 135.0
#                 },
#                 {
#                     "name": "\u6d77\u5916",
#                     "value": 133.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 128.0
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 115.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 100.0
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 97.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 93.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 88.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 86.0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 78.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 71.0
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 69.0
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 63.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 52.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 50.0
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 39.0
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 38.0
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 35.0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 33.0
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 32.0
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 22.0
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 16.0
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 14.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 9.0
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1.0
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": false
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 480,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_e79f254893414d14a510c86ffe5bf41b.setOption(option_e79f254893414d14a510c86ffe5bf41b);
#
#     });
# </script>
